# %%
import xml.etree.ElementTree as ET

def extract_annotations(inkml_path):
    tree = ET.parse(inkml_path)
    root = tree.getroot()
    
    namespace = {'ink': 'http://www.w3.org/2003/InkML'}
    
    annotations = {}
    for annotation in root.findall('ink:annotation', namespace):
        annotations[annotation.get('type')] = annotation.text
        
    annotation_xml = {}
    for annotation in root.findall('ink:annotationXML', namespace):
        annotation_xml[annotation.get('type')] = ET.tostring(annotation, encoding='unicode')
        
    traces = []
    for trace in root.findall('ink:trace', namespace):
        trace_id = trace.get('id')
        trace_data = trace.text.strip().split(', ')
        trace_points = [tuple(map(float, point.split())) for point in trace_data]
        traces.append((trace_id, trace_points))
    
    return annotations, annotation_xml, traces

# %%
import os

train_folders = [
    'archive/CROHME_training_2011/',
    'archive/MatricesTrain2014/',
    'archive/trainData_2012_part1/',
    'archive/trainData_2012_part2/',
    'archive/TrainINKML_2013/',
]

test_folders = [
    'archive/CROHME_test_2011',
    'archive/MatricesTest2014/',
    'archive/testData_2012/',
    'archive/TestINKML_2013/',
]

for folder in train_folders + test_folders:
    assert os.path.exists(folder), f"Path {folder} does not exist"

# %%
import csv
import os
from inkml2png import inkml2img

train_counter = 0
train_output_folder = 'data/train/'
csv_file_path = 'data/annotations.csv'
successes = 0
failures = 0
failed_files = []

os.makedirs(train_output_folder, exist_ok=True)

with open(csv_file_path, mode='w', newline='', encoding='utf-8') as file:
    csv_writer = csv.writer(file)
    csv_writer.writerow(['path', 'age', 'gender', 'hand', 'writer', 'truth', 'ui', 'copyright'])

    for folder in train_folders:
        for filename in os.listdir(folder):
            if filename.endswith('.inkml'):
                input_path = os.path.join(folder, filename)
                output_path = os.path.join(train_output_folder, f'{train_counter}.png')
                            
                try:
                    inkml2img(input_path, output_path)
                    annotations, _, _ = extract_annotations(input_path)
                    
                    age = annotations.get('age', '')
                    gender = annotations.get('gender', '')
                    hand = annotations.get('hand', '')
                    writer = annotations.get('writer', '')
                    truth = annotations.get('truth', '')
                    ui = annotations.get('UI', '')
                    copyright = annotations.get('copyright', '')
                    
                    csv_writer.writerow([f'{train_counter}.png', age, gender, hand, writer, truth, ui, copyright])

                    print(f'Converted: {input_path} -> {output_path}')
                    train_counter += 1
                    successes += 1
                except:
                    print(f'Failed: {input_path}')
                    failures += 1
                    failed_files.append(input_path)
                    continue

print(f'Successes: {successes}, Failures: {failures}')
# Out:
# Converted: archive/CROHME_training_2011/TrainData1_0_sub_1.inkml -> data/train/0.png
# Converted: archive/CROHME_training_2011/TrainData1_0_sub_12.inkml -> data/train/1.png
# Converted: archive/CROHME_training_2011/TrainData1_0_sub_15.inkml -> data/train/2.png
# Converted: archive/CROHME_training_2011/TrainData1_0_sub_19.inkml -> data/train/3.png
# Converted: archive/CROHME_training_2011/TrainData1_0_sub_21.inkml -> data/train/4.png
# Converted: archive/CROHME_training_2011/TrainData1_0_sub_24.inkml -> data/train/5.png
# Converted: archive/CROHME_training_2011/TrainData1_0_sub_28.inkml -> data/train/6.png
# Converted: archive/CROHME_training_2011/TrainData1_0_sub_3.inkml -> data/train/7.png
# Converted: archive/CROHME_training_2011/TrainData1_0_sub_5.inkml -> data/train/8.png
# Converted: archive/CROHME_training_2011/TrainData1_0_sub_7.inkml -> data/train/9.png
# Converted: archive/CROHME_training_2011/TrainData1_0_sub_9.inkml -> data/train/10.png
# Converted: archive/CROHME_training_2011/TrainData1_1_sub_1.inkml -> data/train/11.png
# Converted: archive/CROHME_training_2011/TrainData1_1_sub_12.inkml -> data/train/12.png
# Converted: archive/CROHME_training_2011/TrainData1_1_sub_15.inkml -> data/train/13.png
# Converted: archive/CROHME_training_2011/TrainData1_1_sub_19.inkml -> data/train/14.png
# Converted: archive/CROHME_training_2011/TrainData1_1_sub_21.inkml -> data/train/15.png
# Converted: archive/CROHME_training_2011/TrainData1_1_sub_24.inkml -> data/train/16.png
# Converted: archive/CROHME_training_2011/TrainData1_1_sub_28.inkml -> data/train/17.png
# Converted: archive/CROHME_training_2011/TrainData1_1_sub_3.inkml -> data/train/18.png
# Converted: archive/CROHME_training_2011/TrainData1_1_sub_5.inkml -> data/train/19.png
# Converted: archive/CROHME_training_2011/TrainData1_1_sub_7.inkml -> data/train/20.png
# Converted: archive/CROHME_training_2011/TrainData1_1_sub_9.inkml -> data/train/21.png
# Converted: archive/CROHME_training_2011/TrainData1_2_sub_1.inkml -> data/train/22.png
# Converted: archive/CROHME_training_2011/TrainData1_2_sub_12.inkml -> data/train/23.png
# Converted: archive/CROHME_training_2011/TrainData1_2_sub_15.inkml -> data/train/24.png
# Converted: archive/CROHME_training_2011/TrainData1_2_sub_19.inkml -> data/train/25.png
# Converted: archive/CROHME_training_2011/TrainData1_2_sub_21.inkml -> data/train/26.png
# Converted: archive/CROHME_training_2011/TrainData1_2_sub_24.inkml -> data/train/27.png
# Converted: archive/CROHME_training_2011/TrainData1_2_sub_28.inkml -> data/train/28.png
# Converted: archive/CROHME_training_2011/TrainData1_2_sub_3.inkml -> data/train/29.png
# Converted: archive/CROHME_training_2011/TrainData1_2_sub_5.inkml -> data/train/30.png
# Converted: archive/CROHME_training_2011/TrainData1_2_sub_7.inkml -> data/train/31.png
# Converted: archive/CROHME_training_2011/TrainData1_2_sub_9.inkml -> data/train/32.png
# Converted: archive/CROHME_training_2011/TrainData1_3_sub_1.inkml -> data/train/33.png
# Converted: archive/CROHME_training_2011/TrainData1_3_sub_12.inkml -> data/train/34.png
# Converted: archive/CROHME_training_2011/TrainData1_3_sub_15.inkml -> data/train/35.png
# Converted: archive/CROHME_training_2011/TrainData1_3_sub_19.inkml -> data/train/36.png
# Converted: archive/CROHME_training_2011/TrainData1_3_sub_21.inkml -> data/train/37.png
# Converted: archive/CROHME_training_2011/TrainData1_3_sub_24.inkml -> data/train/38.png
# Converted: archive/CROHME_training_2011/TrainData1_3_sub_28.inkml -> data/train/39.png
# Converted: archive/CROHME_training_2011/TrainData1_3_sub_3.inkml -> data/train/40.png
# Converted: archive/CROHME_training_2011/TrainData1_3_sub_5.inkml -> data/train/41.png
# Converted: archive/CROHME_training_2011/TrainData1_3_sub_7.inkml -> data/train/42.png
# Converted: archive/CROHME_training_2011/TrainData1_3_sub_9.inkml -> data/train/43.png
# Converted: archive/CROHME_training_2011/TrainData1_4_sub_1.inkml -> data/train/44.png
# Converted: archive/CROHME_training_2011/TrainData1_4_sub_12.inkml -> data/train/45.png
# Converted: archive/CROHME_training_2011/TrainData1_4_sub_15.inkml -> data/train/46.png
# Converted: archive/CROHME_training_2011/TrainData1_4_sub_19.inkml -> data/train/47.png
# Converted: archive/CROHME_training_2011/TrainData1_4_sub_21.inkml -> data/train/48.png
# Converted: archive/CROHME_training_2011/TrainData1_4_sub_24.inkml -> data/train/49.png
# Converted: archive/CROHME_training_2011/TrainData1_4_sub_28.inkml -> data/train/50.png
# Converted: archive/CROHME_training_2011/TrainData1_4_sub_3.inkml -> data/train/51.png
# Converted: archive/CROHME_training_2011/TrainData1_4_sub_5.inkml -> data/train/52.png
# Converted: archive/CROHME_training_2011/TrainData1_4_sub_7.inkml -> data/train/53.png
# Converted: archive/CROHME_training_2011/TrainData1_4_sub_9.inkml -> data/train/54.png
# Converted: archive/CROHME_training_2011/TrainData1_5_sub_1.inkml -> data/train/55.png
# Converted: archive/CROHME_training_2011/TrainData1_5_sub_12.inkml -> data/train/56.png
# Converted: archive/CROHME_training_2011/TrainData1_5_sub_15.inkml -> data/train/57.png
# Converted: archive/CROHME_training_2011/TrainData1_5_sub_19.inkml -> data/train/58.png
# Converted: archive/CROHME_training_2011/TrainData1_5_sub_21.inkml -> data/train/59.png
# Converted: archive/CROHME_training_2011/TrainData1_5_sub_24.inkml -> data/train/60.png
# Converted: archive/CROHME_training_2011/TrainData1_5_sub_28.inkml -> data/train/61.png
# Converted: archive/CROHME_training_2011/TrainData1_5_sub_3.inkml -> data/train/62.png
# Converted: archive/CROHME_training_2011/TrainData1_5_sub_5.inkml -> data/train/63.png
# Converted: archive/CROHME_training_2011/TrainData1_5_sub_7.inkml -> data/train/64.png
# Converted: archive/CROHME_training_2011/TrainData1_5_sub_9.inkml -> data/train/65.png
# Converted: archive/CROHME_training_2011/TrainData1_6_sub_1.inkml -> data/train/66.png
# Converted: archive/CROHME_training_2011/TrainData1_6_sub_12.inkml -> data/train/67.png
# Converted: archive/CROHME_training_2011/TrainData1_6_sub_15.inkml -> data/train/68.png
# Converted: archive/CROHME_training_2011/TrainData1_6_sub_19.inkml -> data/train/69.png
# Converted: archive/CROHME_training_2011/TrainData1_6_sub_21.inkml -> data/train/70.png
# Converted: archive/CROHME_training_2011/TrainData1_6_sub_24.inkml -> data/train/71.png
# Converted: archive/CROHME_training_2011/TrainData1_6_sub_28.inkml -> data/train/72.png
# Converted: archive/CROHME_training_2011/TrainData1_6_sub_3.inkml -> data/train/73.png
# Converted: archive/CROHME_training_2011/TrainData1_6_sub_5.inkml -> data/train/74.png
# Converted: archive/CROHME_training_2011/TrainData1_6_sub_7.inkml -> data/train/75.png
# Converted: archive/CROHME_training_2011/TrainData1_6_sub_9.inkml -> data/train/76.png
# Converted: archive/CROHME_training_2011/TrainData1_7_sub_1.inkml -> data/train/77.png
# Converted: archive/CROHME_training_2011/TrainData1_7_sub_12.inkml -> data/train/78.png
# Converted: archive/CROHME_training_2011/TrainData1_7_sub_15.inkml -> data/train/79.png
# Converted: archive/CROHME_training_2011/TrainData1_7_sub_19.inkml -> data/train/80.png
# Converted: archive/CROHME_training_2011/TrainData1_7_sub_21.inkml -> data/train/81.png
# Converted: archive/CROHME_training_2011/TrainData1_7_sub_24.inkml -> data/train/82.png
# Converted: archive/CROHME_training_2011/TrainData1_7_sub_28.inkml -> data/train/83.png
# Converted: archive/CROHME_training_2011/TrainData1_7_sub_3.inkml -> data/train/84.png
# Converted: archive/CROHME_training_2011/TrainData1_7_sub_5.inkml -> data/train/85.png
# Converted: archive/CROHME_training_2011/TrainData1_7_sub_7.inkml -> data/train/86.png
# Converted: archive/CROHME_training_2011/TrainData1_7_sub_9.inkml -> data/train/87.png
# Converted: archive/CROHME_training_2011/TrainData1_8_sub_1.inkml -> data/train/88.png
# Converted: archive/CROHME_training_2011/TrainData1_8_sub_12.inkml -> data/train/89.png
# Converted: archive/CROHME_training_2011/TrainData1_8_sub_15.inkml -> data/train/90.png
# Converted: archive/CROHME_training_2011/TrainData1_8_sub_19.inkml -> data/train/91.png
# Converted: archive/CROHME_training_2011/TrainData1_8_sub_21.inkml -> data/train/92.png
# Converted: archive/CROHME_training_2011/TrainData1_8_sub_24.inkml -> data/train/93.png
# Converted: archive/CROHME_training_2011/TrainData1_8_sub_28.inkml -> data/train/94.png
# Converted: archive/CROHME_training_2011/TrainData1_8_sub_3.inkml -> data/train/95.png
# Converted: archive/CROHME_training_2011/TrainData1_8_sub_5.inkml -> data/train/96.png
# Converted: archive/CROHME_training_2011/TrainData1_8_sub_7.inkml -> data/train/97.png
# Converted: archive/CROHME_training_2011/TrainData1_8_sub_9.inkml -> data/train/98.png
# Converted: archive/CROHME_training_2011/TrainData2_0_sub_1.inkml -> data/train/99.png
# Converted: archive/CROHME_training_2011/TrainData2_0_sub_11.inkml -> data/train/100.png
# Converted: archive/CROHME_training_2011/TrainData2_0_sub_13.inkml -> data/train/101.png
# Converted: archive/CROHME_training_2011/TrainData2_0_sub_15.inkml -> data/train/102.png
# Converted: archive/CROHME_training_2011/TrainData2_0_sub_17.inkml -> data/train/103.png
# Converted: archive/CROHME_training_2011/TrainData2_0_sub_20.inkml -> data/train/104.png
# Converted: archive/CROHME_training_2011/TrainData2_0_sub_29.inkml -> data/train/105.png
# Converted: archive/CROHME_training_2011/TrainData2_0_sub_33.inkml -> data/train/106.png
# Converted: archive/CROHME_training_2011/TrainData2_0_sub_39.inkml -> data/train/107.png
# Converted: archive/CROHME_training_2011/TrainData2_0_sub_41.inkml -> data/train/108.png
# Converted: archive/CROHME_training_2011/TrainData2_0_sub_43.inkml -> data/train/109.png
# Converted: archive/CROHME_training_2011/TrainData2_0_sub_46.inkml -> data/train/110.png
# Converted: archive/CROHME_training_2011/TrainData2_0_sub_49.inkml -> data/train/111.png
# Converted: archive/CROHME_training_2011/TrainData2_0_sub_51.inkml -> data/train/112.png
# Converted: archive/CROHME_training_2011/TrainData2_0_sub_6.inkml -> data/train/113.png
# Converted: archive/CROHME_training_2011/TrainData2_0_sub_61.inkml -> data/train/114.png
# Converted: archive/CROHME_training_2011/TrainData2_0_sub_63.inkml -> data/train/115.png
# Converted: archive/CROHME_training_2011/TrainData2_0_sub_71.inkml -> data/train/116.png
# Converted: archive/CROHME_training_2011/TrainData2_0_sub_73.inkml -> data/train/117.png
# Converted: archive/CROHME_training_2011/TrainData2_0_sub_88.inkml -> data/train/118.png
# Converted: archive/CROHME_training_2011/TrainData2_0_sub_9.inkml -> data/train/119.png
# Converted: archive/CROHME_training_2011/TrainData2_0_sub_95.inkml -> data/train/120.png
# Converted: archive/CROHME_training_2011/TrainData2_0_sub_98.inkml -> data/train/121.png
# Converted: archive/CROHME_training_2011/TrainData2_10_sub_1.inkml -> data/train/122.png
# Converted: archive/CROHME_training_2011/TrainData2_10_sub_11.inkml -> data/train/123.png
# Converted: archive/CROHME_training_2011/TrainData2_10_sub_13.inkml -> data/train/124.png
# Converted: archive/CROHME_training_2011/TrainData2_10_sub_15.inkml -> data/train/125.png
# Converted: archive/CROHME_training_2011/TrainData2_10_sub_17.inkml -> data/train/126.png
# Converted: archive/CROHME_training_2011/TrainData2_10_sub_20.inkml -> data/train/127.png
# Converted: archive/CROHME_training_2011/TrainData2_10_sub_29.inkml -> data/train/128.png
# Converted: archive/CROHME_training_2011/TrainData2_10_sub_33.inkml -> data/train/129.png
# Converted: archive/CROHME_training_2011/TrainData2_10_sub_39.inkml -> data/train/130.png
# Converted: archive/CROHME_training_2011/TrainData2_10_sub_41.inkml -> data/train/131.png
# Converted: archive/CROHME_training_2011/TrainData2_10_sub_43.inkml -> data/train/132.png
# Converted: archive/CROHME_training_2011/TrainData2_10_sub_46.inkml -> data/train/133.png
# Converted: archive/CROHME_training_2011/TrainData2_10_sub_49.inkml -> data/train/134.png
# Converted: archive/CROHME_training_2011/TrainData2_10_sub_51.inkml -> data/train/135.png
# Converted: archive/CROHME_training_2011/TrainData2_10_sub_6.inkml -> data/train/136.png
# Converted: archive/CROHME_training_2011/TrainData2_10_sub_61.inkml -> data/train/137.png
# Converted: archive/CROHME_training_2011/TrainData2_10_sub_63.inkml -> data/train/138.png
# Converted: archive/CROHME_training_2011/TrainData2_10_sub_71.inkml -> data/train/139.png
# Converted: archive/CROHME_training_2011/TrainData2_10_sub_73.inkml -> data/train/140.png
# Converted: archive/CROHME_training_2011/TrainData2_10_sub_88.inkml -> data/train/141.png
# Converted: archive/CROHME_training_2011/TrainData2_10_sub_9.inkml -> data/train/142.png
# Converted: archive/CROHME_training_2011/TrainData2_10_sub_95.inkml -> data/train/143.png
# Converted: archive/CROHME_training_2011/TrainData2_10_sub_98.inkml -> data/train/144.png
# Converted: archive/CROHME_training_2011/TrainData2_11_sub_1.inkml -> data/train/145.png
# Converted: archive/CROHME_training_2011/TrainData2_11_sub_11.inkml -> data/train/146.png
# Converted: archive/CROHME_training_2011/TrainData2_11_sub_13.inkml -> data/train/147.png
# Converted: archive/CROHME_training_2011/TrainData2_11_sub_15.inkml -> data/train/148.png
# Converted: archive/CROHME_training_2011/TrainData2_11_sub_17.inkml -> data/train/149.png
# Converted: archive/CROHME_training_2011/TrainData2_11_sub_20.inkml -> data/train/150.png
# Converted: archive/CROHME_training_2011/TrainData2_11_sub_29.inkml -> data/train/151.png
# Converted: archive/CROHME_training_2011/TrainData2_11_sub_33.inkml -> data/train/152.png
# Converted: archive/CROHME_training_2011/TrainData2_11_sub_39.inkml -> data/train/153.png
# Converted: archive/CROHME_training_2011/TrainData2_11_sub_41.inkml -> data/train/154.png
# Converted: archive/CROHME_training_2011/TrainData2_11_sub_43.inkml -> data/train/155.png
# Converted: archive/CROHME_training_2011/TrainData2_11_sub_46.inkml -> data/train/156.png
# Converted: archive/CROHME_training_2011/TrainData2_11_sub_49.inkml -> data/train/157.png
# Converted: archive/CROHME_training_2011/TrainData2_11_sub_51.inkml -> data/train/158.png
# Converted: archive/CROHME_training_2011/TrainData2_11_sub_6.inkml -> data/train/159.png
# Converted: archive/CROHME_training_2011/TrainData2_11_sub_61.inkml -> data/train/160.png
# Converted: archive/CROHME_training_2011/TrainData2_11_sub_63.inkml -> data/train/161.png
# Converted: archive/CROHME_training_2011/TrainData2_11_sub_71.inkml -> data/train/162.png
# Converted: archive/CROHME_training_2011/TrainData2_11_sub_73.inkml -> data/train/163.png
# Converted: archive/CROHME_training_2011/TrainData2_11_sub_88.inkml -> data/train/164.png
# Converted: archive/CROHME_training_2011/TrainData2_11_sub_9.inkml -> data/train/165.png
# Converted: archive/CROHME_training_2011/TrainData2_11_sub_95.inkml -> data/train/166.png
# Converted: archive/CROHME_training_2011/TrainData2_11_sub_98.inkml -> data/train/167.png
# Converted: archive/CROHME_training_2011/TrainData2_12_sub_1.inkml -> data/train/168.png
# Converted: archive/CROHME_training_2011/TrainData2_12_sub_11.inkml -> data/train/169.png
# Converted: archive/CROHME_training_2011/TrainData2_12_sub_13.inkml -> data/train/170.png
# Converted: archive/CROHME_training_2011/TrainData2_12_sub_15.inkml -> data/train/171.png
# Converted: archive/CROHME_training_2011/TrainData2_12_sub_17.inkml -> data/train/172.png
# Converted: archive/CROHME_training_2011/TrainData2_12_sub_20.inkml -> data/train/173.png
# Converted: archive/CROHME_training_2011/TrainData2_12_sub_29.inkml -> data/train/174.png
# Converted: archive/CROHME_training_2011/TrainData2_12_sub_33.inkml -> data/train/175.png
# Converted: archive/CROHME_training_2011/TrainData2_12_sub_39.inkml -> data/train/176.png
# Converted: archive/CROHME_training_2011/TrainData2_12_sub_41.inkml -> data/train/177.png
# Converted: archive/CROHME_training_2011/TrainData2_12_sub_43.inkml -> data/train/178.png
# Converted: archive/CROHME_training_2011/TrainData2_12_sub_46.inkml -> data/train/179.png
# Converted: archive/CROHME_training_2011/TrainData2_12_sub_49.inkml -> data/train/180.png
# Converted: archive/CROHME_training_2011/TrainData2_12_sub_51.inkml -> data/train/181.png
# Converted: archive/CROHME_training_2011/TrainData2_12_sub_6.inkml -> data/train/182.png
# Converted: archive/CROHME_training_2011/TrainData2_12_sub_61.inkml -> data/train/183.png
# Converted: archive/CROHME_training_2011/TrainData2_12_sub_63.inkml -> data/train/184.png
# Converted: archive/CROHME_training_2011/TrainData2_12_sub_71.inkml -> data/train/185.png
# Converted: archive/CROHME_training_2011/TrainData2_12_sub_73.inkml -> data/train/186.png
# Converted: archive/CROHME_training_2011/TrainData2_12_sub_88.inkml -> data/train/187.png
# Converted: archive/CROHME_training_2011/TrainData2_12_sub_9.inkml -> data/train/188.png
# Converted: archive/CROHME_training_2011/TrainData2_12_sub_95.inkml -> data/train/189.png
# Converted: archive/CROHME_training_2011/TrainData2_12_sub_98.inkml -> data/train/190.png
# Converted: archive/CROHME_training_2011/TrainData2_13_sub_1.inkml -> data/train/191.png
# Converted: archive/CROHME_training_2011/TrainData2_13_sub_11.inkml -> data/train/192.png
# Converted: archive/CROHME_training_2011/TrainData2_13_sub_13.inkml -> data/train/193.png
# Converted: archive/CROHME_training_2011/TrainData2_13_sub_15.inkml -> data/train/194.png
# Converted: archive/CROHME_training_2011/TrainData2_13_sub_17.inkml -> data/train/195.png
# Converted: archive/CROHME_training_2011/TrainData2_13_sub_20.inkml -> data/train/196.png
# Converted: archive/CROHME_training_2011/TrainData2_13_sub_29.inkml -> data/train/197.png
# Converted: archive/CROHME_training_2011/TrainData2_13_sub_33.inkml -> data/train/198.png
# Converted: archive/CROHME_training_2011/TrainData2_13_sub_39.inkml -> data/train/199.png
# Converted: archive/CROHME_training_2011/TrainData2_13_sub_41.inkml -> data/train/200.png
# Converted: archive/CROHME_training_2011/TrainData2_13_sub_43.inkml -> data/train/201.png
# Converted: archive/CROHME_training_2011/TrainData2_13_sub_46.inkml -> data/train/202.png
# Converted: archive/CROHME_training_2011/TrainData2_13_sub_49.inkml -> data/train/203.png
# Converted: archive/CROHME_training_2011/TrainData2_13_sub_51.inkml -> data/train/204.png
# Converted: archive/CROHME_training_2011/TrainData2_13_sub_6.inkml -> data/train/205.png
# Converted: archive/CROHME_training_2011/TrainData2_13_sub_61.inkml -> data/train/206.png
# Converted: archive/CROHME_training_2011/TrainData2_13_sub_63.inkml -> data/train/207.png
# Converted: archive/CROHME_training_2011/TrainData2_13_sub_71.inkml -> data/train/208.png
# Converted: archive/CROHME_training_2011/TrainData2_13_sub_73.inkml -> data/train/209.png
# Converted: archive/CROHME_training_2011/TrainData2_13_sub_88.inkml -> data/train/210.png
# Converted: archive/CROHME_training_2011/TrainData2_13_sub_9.inkml -> data/train/211.png
# Converted: archive/CROHME_training_2011/TrainData2_13_sub_95.inkml -> data/train/212.png
# Converted: archive/CROHME_training_2011/TrainData2_13_sub_98.inkml -> data/train/213.png
# Converted: archive/CROHME_training_2011/TrainData2_14_sub_1.inkml -> data/train/214.png
# Converted: archive/CROHME_training_2011/TrainData2_14_sub_11.inkml -> data/train/215.png
# Converted: archive/CROHME_training_2011/TrainData2_14_sub_13.inkml -> data/train/216.png
# Converted: archive/CROHME_training_2011/TrainData2_14_sub_15.inkml -> data/train/217.png
# Converted: archive/CROHME_training_2011/TrainData2_14_sub_17.inkml -> data/train/218.png
# Converted: archive/CROHME_training_2011/TrainData2_14_sub_20.inkml -> data/train/219.png
# Converted: archive/CROHME_training_2011/TrainData2_14_sub_29.inkml -> data/train/220.png
# Converted: archive/CROHME_training_2011/TrainData2_14_sub_33.inkml -> data/train/221.png
# Converted: archive/CROHME_training_2011/TrainData2_14_sub_39.inkml -> data/train/222.png
# Converted: archive/CROHME_training_2011/TrainData2_14_sub_41.inkml -> data/train/223.png
# Converted: archive/CROHME_training_2011/TrainData2_14_sub_43.inkml -> data/train/224.png
# Converted: archive/CROHME_training_2011/TrainData2_14_sub_46.inkml -> data/train/225.png
# Converted: archive/CROHME_training_2011/TrainData2_14_sub_49.inkml -> data/train/226.png
# Converted: archive/CROHME_training_2011/TrainData2_14_sub_51.inkml -> data/train/227.png
# Converted: archive/CROHME_training_2011/TrainData2_14_sub_6.inkml -> data/train/228.png
# Converted: archive/CROHME_training_2011/TrainData2_14_sub_61.inkml -> data/train/229.png
# Converted: archive/CROHME_training_2011/TrainData2_14_sub_63.inkml -> data/train/230.png
# Converted: archive/CROHME_training_2011/TrainData2_14_sub_71.inkml -> data/train/231.png
# Converted: archive/CROHME_training_2011/TrainData2_14_sub_73.inkml -> data/train/232.png
# Converted: archive/CROHME_training_2011/TrainData2_14_sub_88.inkml -> data/train/233.png
# Converted: archive/CROHME_training_2011/TrainData2_14_sub_9.inkml -> data/train/234.png
# Converted: archive/CROHME_training_2011/TrainData2_14_sub_95.inkml -> data/train/235.png
# Converted: archive/CROHME_training_2011/TrainData2_14_sub_98.inkml -> data/train/236.png
# Converted: archive/CROHME_training_2011/TrainData2_15_sub_1.inkml -> data/train/237.png
# Converted: archive/CROHME_training_2011/TrainData2_15_sub_11.inkml -> data/train/238.png
# Converted: archive/CROHME_training_2011/TrainData2_15_sub_13.inkml -> data/train/239.png
# Converted: archive/CROHME_training_2011/TrainData2_15_sub_15.inkml -> data/train/240.png
# Converted: archive/CROHME_training_2011/TrainData2_15_sub_17.inkml -> data/train/241.png
# Converted: archive/CROHME_training_2011/TrainData2_15_sub_20.inkml -> data/train/242.png
# Converted: archive/CROHME_training_2011/TrainData2_15_sub_29.inkml -> data/train/243.png
# Converted: archive/CROHME_training_2011/TrainData2_15_sub_33.inkml -> data/train/244.png
# Converted: archive/CROHME_training_2011/TrainData2_15_sub_39.inkml -> data/train/245.png
# Converted: archive/CROHME_training_2011/TrainData2_15_sub_41.inkml -> data/train/246.png
# Converted: archive/CROHME_training_2011/TrainData2_15_sub_43.inkml -> data/train/247.png
# Converted: archive/CROHME_training_2011/TrainData2_15_sub_46.inkml -> data/train/248.png
# Converted: archive/CROHME_training_2011/TrainData2_15_sub_49.inkml -> data/train/249.png
# Converted: archive/CROHME_training_2011/TrainData2_15_sub_51.inkml -> data/train/250.png
# Converted: archive/CROHME_training_2011/TrainData2_15_sub_6.inkml -> data/train/251.png
# Converted: archive/CROHME_training_2011/TrainData2_15_sub_61.inkml -> data/train/252.png
# Converted: archive/CROHME_training_2011/TrainData2_15_sub_63.inkml -> data/train/253.png
# Converted: archive/CROHME_training_2011/TrainData2_15_sub_71.inkml -> data/train/254.png
# Converted: archive/CROHME_training_2011/TrainData2_15_sub_73.inkml -> data/train/255.png
# Converted: archive/CROHME_training_2011/TrainData2_15_sub_88.inkml -> data/train/256.png
# Converted: archive/CROHME_training_2011/TrainData2_15_sub_9.inkml -> data/train/257.png
# Converted: archive/CROHME_training_2011/TrainData2_15_sub_95.inkml -> data/train/258.png
# Converted: archive/CROHME_training_2011/TrainData2_15_sub_98.inkml -> data/train/259.png
# Converted: archive/CROHME_training_2011/TrainData2_16_sub_1.inkml -> data/train/260.png
# Converted: archive/CROHME_training_2011/TrainData2_16_sub_11.inkml -> data/train/261.png
# Converted: archive/CROHME_training_2011/TrainData2_16_sub_13.inkml -> data/train/262.png
# Converted: archive/CROHME_training_2011/TrainData2_16_sub_15.inkml -> data/train/263.png
# Converted: archive/CROHME_training_2011/TrainData2_16_sub_17.inkml -> data/train/264.png
# Converted: archive/CROHME_training_2011/TrainData2_16_sub_20.inkml -> data/train/265.png
# Converted: archive/CROHME_training_2011/TrainData2_16_sub_29.inkml -> data/train/266.png
# Converted: archive/CROHME_training_2011/TrainData2_16_sub_33.inkml -> data/train/267.png
# Converted: archive/CROHME_training_2011/TrainData2_16_sub_39.inkml -> data/train/268.png
# Converted: archive/CROHME_training_2011/TrainData2_16_sub_41.inkml -> data/train/269.png
# Converted: archive/CROHME_training_2011/TrainData2_16_sub_43.inkml -> data/train/270.png
# Converted: archive/CROHME_training_2011/TrainData2_16_sub_46.inkml -> data/train/271.png
# Converted: archive/CROHME_training_2011/TrainData2_16_sub_49.inkml -> data/train/272.png
# Converted: archive/CROHME_training_2011/TrainData2_16_sub_51.inkml -> data/train/273.png
# Converted: archive/CROHME_training_2011/TrainData2_16_sub_6.inkml -> data/train/274.png
# Converted: archive/CROHME_training_2011/TrainData2_16_sub_61.inkml -> data/train/275.png
# Converted: archive/CROHME_training_2011/TrainData2_16_sub_63.inkml -> data/train/276.png
# Converted: archive/CROHME_training_2011/TrainData2_16_sub_71.inkml -> data/train/277.png
# Converted: archive/CROHME_training_2011/TrainData2_16_sub_73.inkml -> data/train/278.png
# Converted: archive/CROHME_training_2011/TrainData2_16_sub_88.inkml -> data/train/279.png
# Converted: archive/CROHME_training_2011/TrainData2_16_sub_9.inkml -> data/train/280.png
# Converted: archive/CROHME_training_2011/TrainData2_16_sub_95.inkml -> data/train/281.png
# Converted: archive/CROHME_training_2011/TrainData2_16_sub_98.inkml -> data/train/282.png
# Converted: archive/CROHME_training_2011/TrainData2_17_sub_1.inkml -> data/train/283.png
# Converted: archive/CROHME_training_2011/TrainData2_17_sub_11.inkml -> data/train/284.png
# Converted: archive/CROHME_training_2011/TrainData2_17_sub_13.inkml -> data/train/285.png
# Converted: archive/CROHME_training_2011/TrainData2_17_sub_15.inkml -> data/train/286.png
# Converted: archive/CROHME_training_2011/TrainData2_17_sub_17.inkml -> data/train/287.png
# Converted: archive/CROHME_training_2011/TrainData2_17_sub_20.inkml -> data/train/288.png
# Converted: archive/CROHME_training_2011/TrainData2_17_sub_29.inkml -> data/train/289.png
# Converted: archive/CROHME_training_2011/TrainData2_17_sub_33.inkml -> data/train/290.png
# Converted: archive/CROHME_training_2011/TrainData2_17_sub_39.inkml -> data/train/291.png
# Converted: archive/CROHME_training_2011/TrainData2_17_sub_41.inkml -> data/train/292.png
# Converted: archive/CROHME_training_2011/TrainData2_17_sub_43.inkml -> data/train/293.png
# Converted: archive/CROHME_training_2011/TrainData2_17_sub_46.inkml -> data/train/294.png
# Converted: archive/CROHME_training_2011/TrainData2_17_sub_49.inkml -> data/train/295.png
# Converted: archive/CROHME_training_2011/TrainData2_17_sub_51.inkml -> data/train/296.png
# Converted: archive/CROHME_training_2011/TrainData2_17_sub_6.inkml -> data/train/297.png
# Converted: archive/CROHME_training_2011/TrainData2_17_sub_61.inkml -> data/train/298.png
# Converted: archive/CROHME_training_2011/TrainData2_17_sub_63.inkml -> data/train/299.png
# Converted: archive/CROHME_training_2011/TrainData2_17_sub_71.inkml -> data/train/300.png
# Converted: archive/CROHME_training_2011/TrainData2_17_sub_73.inkml -> data/train/301.png
# Converted: archive/CROHME_training_2011/TrainData2_17_sub_88.inkml -> data/train/302.png
# Converted: archive/CROHME_training_2011/TrainData2_17_sub_9.inkml -> data/train/303.png
# Converted: archive/CROHME_training_2011/TrainData2_17_sub_95.inkml -> data/train/304.png
# Converted: archive/CROHME_training_2011/TrainData2_17_sub_98.inkml -> data/train/305.png
# Converted: archive/CROHME_training_2011/TrainData2_18_sub_1.inkml -> data/train/306.png
# Converted: archive/CROHME_training_2011/TrainData2_18_sub_11.inkml -> data/train/307.png
# Converted: archive/CROHME_training_2011/TrainData2_18_sub_13.inkml -> data/train/308.png
# Converted: archive/CROHME_training_2011/TrainData2_18_sub_15.inkml -> data/train/309.png
# Converted: archive/CROHME_training_2011/TrainData2_18_sub_17.inkml -> data/train/310.png
# Converted: archive/CROHME_training_2011/TrainData2_18_sub_20.inkml -> data/train/311.png
# Converted: archive/CROHME_training_2011/TrainData2_18_sub_29.inkml -> data/train/312.png
# Converted: archive/CROHME_training_2011/TrainData2_18_sub_33.inkml -> data/train/313.png
# Converted: archive/CROHME_training_2011/TrainData2_18_sub_39.inkml -> data/train/314.png
# Converted: archive/CROHME_training_2011/TrainData2_18_sub_41.inkml -> data/train/315.png
# Converted: archive/CROHME_training_2011/TrainData2_18_sub_43.inkml -> data/train/316.png
# Converted: archive/CROHME_training_2011/TrainData2_18_sub_46.inkml -> data/train/317.png
# Converted: archive/CROHME_training_2011/TrainData2_18_sub_49.inkml -> data/train/318.png
# Converted: archive/CROHME_training_2011/TrainData2_18_sub_51.inkml -> data/train/319.png
# Converted: archive/CROHME_training_2011/TrainData2_18_sub_6.inkml -> data/train/320.png
# Converted: archive/CROHME_training_2011/TrainData2_18_sub_61.inkml -> data/train/321.png
# Converted: archive/CROHME_training_2011/TrainData2_18_sub_63.inkml -> data/train/322.png
# Converted: archive/CROHME_training_2011/TrainData2_18_sub_71.inkml -> data/train/323.png
# Converted: archive/CROHME_training_2011/TrainData2_18_sub_73.inkml -> data/train/324.png
# Converted: archive/CROHME_training_2011/TrainData2_18_sub_88.inkml -> data/train/325.png
# Converted: archive/CROHME_training_2011/TrainData2_18_sub_9.inkml -> data/train/326.png
# Converted: archive/CROHME_training_2011/TrainData2_18_sub_95.inkml -> data/train/327.png
# Converted: archive/CROHME_training_2011/TrainData2_18_sub_98.inkml -> data/train/328.png
# Converted: archive/CROHME_training_2011/TrainData2_19_sub_1.inkml -> data/train/329.png
# Converted: archive/CROHME_training_2011/TrainData2_19_sub_11.inkml -> data/train/330.png
# Converted: archive/CROHME_training_2011/TrainData2_19_sub_13.inkml -> data/train/331.png
# Converted: archive/CROHME_training_2011/TrainData2_19_sub_15.inkml -> data/train/332.png
# Converted: archive/CROHME_training_2011/TrainData2_19_sub_17.inkml -> data/train/333.png
# Converted: archive/CROHME_training_2011/TrainData2_19_sub_20.inkml -> data/train/334.png
# Converted: archive/CROHME_training_2011/TrainData2_19_sub_29.inkml -> data/train/335.png
# Converted: archive/CROHME_training_2011/TrainData2_19_sub_33.inkml -> data/train/336.png
# Converted: archive/CROHME_training_2011/TrainData2_19_sub_39.inkml -> data/train/337.png
# Converted: archive/CROHME_training_2011/TrainData2_19_sub_41.inkml -> data/train/338.png
# Converted: archive/CROHME_training_2011/TrainData2_19_sub_43.inkml -> data/train/339.png
# Converted: archive/CROHME_training_2011/TrainData2_19_sub_46.inkml -> data/train/340.png
# Converted: archive/CROHME_training_2011/TrainData2_19_sub_49.inkml -> data/train/341.png
# Converted: archive/CROHME_training_2011/TrainData2_19_sub_51.inkml -> data/train/342.png
# Converted: archive/CROHME_training_2011/TrainData2_19_sub_6.inkml -> data/train/343.png
# Converted: archive/CROHME_training_2011/TrainData2_19_sub_61.inkml -> data/train/344.png
# Converted: archive/CROHME_training_2011/TrainData2_19_sub_63.inkml -> data/train/345.png
# Converted: archive/CROHME_training_2011/TrainData2_19_sub_71.inkml -> data/train/346.png
# Converted: archive/CROHME_training_2011/TrainData2_19_sub_73.inkml -> data/train/347.png
# Converted: archive/CROHME_training_2011/TrainData2_19_sub_88.inkml -> data/train/348.png
# Converted: archive/CROHME_training_2011/TrainData2_19_sub_9.inkml -> data/train/349.png
# Converted: archive/CROHME_training_2011/TrainData2_19_sub_95.inkml -> data/train/350.png
# Converted: archive/CROHME_training_2011/TrainData2_19_sub_98.inkml -> data/train/351.png
# Converted: archive/CROHME_training_2011/TrainData2_1_sub_1.inkml -> data/train/352.png
# Converted: archive/CROHME_training_2011/TrainData2_1_sub_11.inkml -> data/train/353.png
# Converted: archive/CROHME_training_2011/TrainData2_1_sub_13.inkml -> data/train/354.png
# Converted: archive/CROHME_training_2011/TrainData2_1_sub_15.inkml -> data/train/355.png
# Converted: archive/CROHME_training_2011/TrainData2_1_sub_17.inkml -> data/train/356.png
# Converted: archive/CROHME_training_2011/TrainData2_1_sub_20.inkml -> data/train/357.png
# Converted: archive/CROHME_training_2011/TrainData2_1_sub_29.inkml -> data/train/358.png
# Converted: archive/CROHME_training_2011/TrainData2_1_sub_33.inkml -> data/train/359.png
# Converted: archive/CROHME_training_2011/TrainData2_1_sub_39.inkml -> data/train/360.png
# Converted: archive/CROHME_training_2011/TrainData2_1_sub_41.inkml -> data/train/361.png
# Converted: archive/CROHME_training_2011/TrainData2_1_sub_43.inkml -> data/train/362.png
# Converted: archive/CROHME_training_2011/TrainData2_1_sub_46.inkml -> data/train/363.png
# Converted: archive/CROHME_training_2011/TrainData2_1_sub_49.inkml -> data/train/364.png
# Converted: archive/CROHME_training_2011/TrainData2_1_sub_51.inkml -> data/train/365.png
# Converted: archive/CROHME_training_2011/TrainData2_1_sub_6.inkml -> data/train/366.png
# Converted: archive/CROHME_training_2011/TrainData2_1_sub_61.inkml -> data/train/367.png
# Converted: archive/CROHME_training_2011/TrainData2_1_sub_63.inkml -> data/train/368.png
# Converted: archive/CROHME_training_2011/TrainData2_1_sub_71.inkml -> data/train/369.png
# Converted: archive/CROHME_training_2011/TrainData2_1_sub_73.inkml -> data/train/370.png
# Converted: archive/CROHME_training_2011/TrainData2_1_sub_88.inkml -> data/train/371.png
# Converted: archive/CROHME_training_2011/TrainData2_1_sub_9.inkml -> data/train/372.png
# Converted: archive/CROHME_training_2011/TrainData2_1_sub_95.inkml -> data/train/373.png
# Converted: archive/CROHME_training_2011/TrainData2_1_sub_98.inkml -> data/train/374.png
# Converted: archive/CROHME_training_2011/TrainData2_20_sub_1.inkml -> data/train/375.png
# Converted: archive/CROHME_training_2011/TrainData2_20_sub_11.inkml -> data/train/376.png
# Converted: archive/CROHME_training_2011/TrainData2_20_sub_13.inkml -> data/train/377.png
# Converted: archive/CROHME_training_2011/TrainData2_20_sub_15.inkml -> data/train/378.png
# Converted: archive/CROHME_training_2011/TrainData2_20_sub_17.inkml -> data/train/379.png
# Converted: archive/CROHME_training_2011/TrainData2_20_sub_20.inkml -> data/train/380.png
# Converted: archive/CROHME_training_2011/TrainData2_20_sub_29.inkml -> data/train/381.png
# Converted: archive/CROHME_training_2011/TrainData2_20_sub_33.inkml -> data/train/382.png
# Converted: archive/CROHME_training_2011/TrainData2_20_sub_39.inkml -> data/train/383.png
# Converted: archive/CROHME_training_2011/TrainData2_20_sub_41.inkml -> data/train/384.png
# Converted: archive/CROHME_training_2011/TrainData2_20_sub_43.inkml -> data/train/385.png
# Converted: archive/CROHME_training_2011/TrainData2_20_sub_46.inkml -> data/train/386.png
# Converted: archive/CROHME_training_2011/TrainData2_20_sub_49.inkml -> data/train/387.png
# Converted: archive/CROHME_training_2011/TrainData2_20_sub_51.inkml -> data/train/388.png
# Converted: archive/CROHME_training_2011/TrainData2_20_sub_6.inkml -> data/train/389.png
# Converted: archive/CROHME_training_2011/TrainData2_20_sub_61.inkml -> data/train/390.png
# Converted: archive/CROHME_training_2011/TrainData2_20_sub_63.inkml -> data/train/391.png
# Converted: archive/CROHME_training_2011/TrainData2_20_sub_71.inkml -> data/train/392.png
# Converted: archive/CROHME_training_2011/TrainData2_20_sub_73.inkml -> data/train/393.png
# Converted: archive/CROHME_training_2011/TrainData2_20_sub_88.inkml -> data/train/394.png
# Converted: archive/CROHME_training_2011/TrainData2_20_sub_9.inkml -> data/train/395.png
# Converted: archive/CROHME_training_2011/TrainData2_20_sub_95.inkml -> data/train/396.png
# Converted: archive/CROHME_training_2011/TrainData2_20_sub_98.inkml -> data/train/397.png
# Converted: archive/CROHME_training_2011/TrainData2_21_sub_1.inkml -> data/train/398.png
# Converted: archive/CROHME_training_2011/TrainData2_21_sub_11.inkml -> data/train/399.png
# Converted: archive/CROHME_training_2011/TrainData2_21_sub_13.inkml -> data/train/400.png
# Converted: archive/CROHME_training_2011/TrainData2_21_sub_15.inkml -> data/train/401.png
# Converted: archive/CROHME_training_2011/TrainData2_21_sub_17.inkml -> data/train/402.png
# Converted: archive/CROHME_training_2011/TrainData2_21_sub_20.inkml -> data/train/403.png
# Converted: archive/CROHME_training_2011/TrainData2_21_sub_29.inkml -> data/train/404.png
# Converted: archive/CROHME_training_2011/TrainData2_21_sub_33.inkml -> data/train/405.png
# Converted: archive/CROHME_training_2011/TrainData2_21_sub_39.inkml -> data/train/406.png
# Converted: archive/CROHME_training_2011/TrainData2_21_sub_41.inkml -> data/train/407.png
# Converted: archive/CROHME_training_2011/TrainData2_21_sub_43.inkml -> data/train/408.png
# Converted: archive/CROHME_training_2011/TrainData2_21_sub_46.inkml -> data/train/409.png
# Converted: archive/CROHME_training_2011/TrainData2_21_sub_49.inkml -> data/train/410.png
# Converted: archive/CROHME_training_2011/TrainData2_21_sub_51.inkml -> data/train/411.png
# Converted: archive/CROHME_training_2011/TrainData2_21_sub_6.inkml -> data/train/412.png
# Converted: archive/CROHME_training_2011/TrainData2_21_sub_61.inkml -> data/train/413.png
# Converted: archive/CROHME_training_2011/TrainData2_21_sub_63.inkml -> data/train/414.png
# Converted: archive/CROHME_training_2011/TrainData2_21_sub_71.inkml -> data/train/415.png
# Converted: archive/CROHME_training_2011/TrainData2_21_sub_73.inkml -> data/train/416.png
# Converted: archive/CROHME_training_2011/TrainData2_21_sub_88.inkml -> data/train/417.png
# Converted: archive/CROHME_training_2011/TrainData2_21_sub_9.inkml -> data/train/418.png
# Converted: archive/CROHME_training_2011/TrainData2_21_sub_95.inkml -> data/train/419.png
# Converted: archive/CROHME_training_2011/TrainData2_21_sub_98.inkml -> data/train/420.png
# Converted: archive/CROHME_training_2011/TrainData2_22_sub_1.inkml -> data/train/421.png
# Converted: archive/CROHME_training_2011/TrainData2_22_sub_11.inkml -> data/train/422.png
# Converted: archive/CROHME_training_2011/TrainData2_22_sub_13.inkml -> data/train/423.png
# Converted: archive/CROHME_training_2011/TrainData2_22_sub_15.inkml -> data/train/424.png
# Converted: archive/CROHME_training_2011/TrainData2_22_sub_17.inkml -> data/train/425.png
# Converted: archive/CROHME_training_2011/TrainData2_22_sub_20.inkml -> data/train/426.png
# Converted: archive/CROHME_training_2011/TrainData2_22_sub_29.inkml -> data/train/427.png
# Converted: archive/CROHME_training_2011/TrainData2_22_sub_33.inkml -> data/train/428.png
# Converted: archive/CROHME_training_2011/TrainData2_22_sub_39.inkml -> data/train/429.png
# Converted: archive/CROHME_training_2011/TrainData2_22_sub_41.inkml -> data/train/430.png
# Converted: archive/CROHME_training_2011/TrainData2_22_sub_43.inkml -> data/train/431.png
# Converted: archive/CROHME_training_2011/TrainData2_22_sub_46.inkml -> data/train/432.png
# Converted: archive/CROHME_training_2011/TrainData2_22_sub_49.inkml -> data/train/433.png
# Converted: archive/CROHME_training_2011/TrainData2_22_sub_51.inkml -> data/train/434.png
# Converted: archive/CROHME_training_2011/TrainData2_22_sub_6.inkml -> data/train/435.png
# Converted: archive/CROHME_training_2011/TrainData2_22_sub_61.inkml -> data/train/436.png
# Converted: archive/CROHME_training_2011/TrainData2_22_sub_63.inkml -> data/train/437.png
# Converted: archive/CROHME_training_2011/TrainData2_22_sub_71.inkml -> data/train/438.png
# Converted: archive/CROHME_training_2011/TrainData2_22_sub_73.inkml -> data/train/439.png
# Converted: archive/CROHME_training_2011/TrainData2_22_sub_88.inkml -> data/train/440.png
# Converted: archive/CROHME_training_2011/TrainData2_22_sub_9.inkml -> data/train/441.png
# Converted: archive/CROHME_training_2011/TrainData2_22_sub_95.inkml -> data/train/442.png
# Converted: archive/CROHME_training_2011/TrainData2_22_sub_98.inkml -> data/train/443.png
# Converted: archive/CROHME_training_2011/TrainData2_23_sub_1.inkml -> data/train/444.png
# Converted: archive/CROHME_training_2011/TrainData2_23_sub_11.inkml -> data/train/445.png
# Converted: archive/CROHME_training_2011/TrainData2_23_sub_13.inkml -> data/train/446.png
# Converted: archive/CROHME_training_2011/TrainData2_23_sub_15.inkml -> data/train/447.png
# Converted: archive/CROHME_training_2011/TrainData2_23_sub_17.inkml -> data/train/448.png
# Converted: archive/CROHME_training_2011/TrainData2_23_sub_20.inkml -> data/train/449.png
# Converted: archive/CROHME_training_2011/TrainData2_23_sub_29.inkml -> data/train/450.png
# Converted: archive/CROHME_training_2011/TrainData2_23_sub_33.inkml -> data/train/451.png
# Converted: archive/CROHME_training_2011/TrainData2_23_sub_39.inkml -> data/train/452.png
# Converted: archive/CROHME_training_2011/TrainData2_23_sub_41.inkml -> data/train/453.png
# Converted: archive/CROHME_training_2011/TrainData2_23_sub_43.inkml -> data/train/454.png
# Converted: archive/CROHME_training_2011/TrainData2_23_sub_46.inkml -> data/train/455.png
# Converted: archive/CROHME_training_2011/TrainData2_23_sub_49.inkml -> data/train/456.png
# Converted: archive/CROHME_training_2011/TrainData2_23_sub_51.inkml -> data/train/457.png
# Converted: archive/CROHME_training_2011/TrainData2_23_sub_6.inkml -> data/train/458.png
# Converted: archive/CROHME_training_2011/TrainData2_23_sub_61.inkml -> data/train/459.png
# Converted: archive/CROHME_training_2011/TrainData2_23_sub_63.inkml -> data/train/460.png
# Converted: archive/CROHME_training_2011/TrainData2_23_sub_71.inkml -> data/train/461.png
# Converted: archive/CROHME_training_2011/TrainData2_23_sub_73.inkml -> data/train/462.png
# Converted: archive/CROHME_training_2011/TrainData2_23_sub_88.inkml -> data/train/463.png
# Converted: archive/CROHME_training_2011/TrainData2_23_sub_9.inkml -> data/train/464.png
# Converted: archive/CROHME_training_2011/TrainData2_23_sub_95.inkml -> data/train/465.png
# Converted: archive/CROHME_training_2011/TrainData2_23_sub_98.inkml -> data/train/466.png
# Converted: archive/CROHME_training_2011/TrainData2_24_sub_1.inkml -> data/train/467.png
# Converted: archive/CROHME_training_2011/TrainData2_24_sub_11.inkml -> data/train/468.png
# Converted: archive/CROHME_training_2011/TrainData2_24_sub_13.inkml -> data/train/469.png
# Converted: archive/CROHME_training_2011/TrainData2_24_sub_15.inkml -> data/train/470.png
# Converted: archive/CROHME_training_2011/TrainData2_24_sub_17.inkml -> data/train/471.png
# Converted: archive/CROHME_training_2011/TrainData2_24_sub_20.inkml -> data/train/472.png
# Converted: archive/CROHME_training_2011/TrainData2_24_sub_29.inkml -> data/train/473.png
# Converted: archive/CROHME_training_2011/TrainData2_24_sub_33.inkml -> data/train/474.png
# Converted: archive/CROHME_training_2011/TrainData2_24_sub_39.inkml -> data/train/475.png
# Converted: archive/CROHME_training_2011/TrainData2_24_sub_41.inkml -> data/train/476.png
# Converted: archive/CROHME_training_2011/TrainData2_24_sub_43.inkml -> data/train/477.png
# Converted: archive/CROHME_training_2011/TrainData2_24_sub_46.inkml -> data/train/478.png
# Converted: archive/CROHME_training_2011/TrainData2_24_sub_49.inkml -> data/train/479.png
# Converted: archive/CROHME_training_2011/TrainData2_24_sub_51.inkml -> data/train/480.png
# Converted: archive/CROHME_training_2011/TrainData2_24_sub_6.inkml -> data/train/481.png
# Converted: archive/CROHME_training_2011/TrainData2_24_sub_61.inkml -> data/train/482.png
# Converted: archive/CROHME_training_2011/TrainData2_24_sub_63.inkml -> data/train/483.png
# Converted: archive/CROHME_training_2011/TrainData2_24_sub_71.inkml -> data/train/484.png
# Converted: archive/CROHME_training_2011/TrainData2_24_sub_73.inkml -> data/train/485.png
# Converted: archive/CROHME_training_2011/TrainData2_24_sub_88.inkml -> data/train/486.png
# Converted: archive/CROHME_training_2011/TrainData2_24_sub_9.inkml -> data/train/487.png
# Converted: archive/CROHME_training_2011/TrainData2_24_sub_95.inkml -> data/train/488.png
# Converted: archive/CROHME_training_2011/TrainData2_24_sub_98.inkml -> data/train/489.png
# Converted: archive/CROHME_training_2011/TrainData2_25_sub_1.inkml -> data/train/490.png
# Converted: archive/CROHME_training_2011/TrainData2_25_sub_11.inkml -> data/train/491.png
# Converted: archive/CROHME_training_2011/TrainData2_25_sub_13.inkml -> data/train/492.png
# Converted: archive/CROHME_training_2011/TrainData2_25_sub_15.inkml -> data/train/493.png
# Converted: archive/CROHME_training_2011/TrainData2_25_sub_17.inkml -> data/train/494.png
# Converted: archive/CROHME_training_2011/TrainData2_25_sub_20.inkml -> data/train/495.png
# Converted: archive/CROHME_training_2011/TrainData2_25_sub_29.inkml -> data/train/496.png
# Converted: archive/CROHME_training_2011/TrainData2_25_sub_33.inkml -> data/train/497.png
# Converted: archive/CROHME_training_2011/TrainData2_25_sub_39.inkml -> data/train/498.png
# Converted: archive/CROHME_training_2011/TrainData2_25_sub_41.inkml -> data/train/499.png
# Converted: archive/CROHME_training_2011/TrainData2_25_sub_43.inkml -> data/train/500.png
# Converted: archive/CROHME_training_2011/TrainData2_25_sub_46.inkml -> data/train/501.png
# Converted: archive/CROHME_training_2011/TrainData2_25_sub_49.inkml -> data/train/502.png
# Converted: archive/CROHME_training_2011/TrainData2_25_sub_51.inkml -> data/train/503.png
# Converted: archive/CROHME_training_2011/TrainData2_25_sub_6.inkml -> data/train/504.png
# Converted: archive/CROHME_training_2011/TrainData2_25_sub_61.inkml -> data/train/505.png
# Converted: archive/CROHME_training_2011/TrainData2_25_sub_63.inkml -> data/train/506.png
# Converted: archive/CROHME_training_2011/TrainData2_25_sub_71.inkml -> data/train/507.png
# Converted: archive/CROHME_training_2011/TrainData2_25_sub_73.inkml -> data/train/508.png
# Converted: archive/CROHME_training_2011/TrainData2_25_sub_88.inkml -> data/train/509.png
# Converted: archive/CROHME_training_2011/TrainData2_25_sub_9.inkml -> data/train/510.png
# Converted: archive/CROHME_training_2011/TrainData2_25_sub_95.inkml -> data/train/511.png
# Converted: archive/CROHME_training_2011/TrainData2_25_sub_98.inkml -> data/train/512.png
# Converted: archive/CROHME_training_2011/TrainData2_26_sub_1.inkml -> data/train/513.png
# Converted: archive/CROHME_training_2011/TrainData2_26_sub_11.inkml -> data/train/514.png
# Converted: archive/CROHME_training_2011/TrainData2_26_sub_13.inkml -> data/train/515.png
# Converted: archive/CROHME_training_2011/TrainData2_26_sub_15.inkml -> data/train/516.png
# Converted: archive/CROHME_training_2011/TrainData2_26_sub_17.inkml -> data/train/517.png
# Converted: archive/CROHME_training_2011/TrainData2_26_sub_20.inkml -> data/train/518.png
# Converted: archive/CROHME_training_2011/TrainData2_26_sub_29.inkml -> data/train/519.png
# Converted: archive/CROHME_training_2011/TrainData2_26_sub_33.inkml -> data/train/520.png
# Converted: archive/CROHME_training_2011/TrainData2_26_sub_39.inkml -> data/train/521.png
# Converted: archive/CROHME_training_2011/TrainData2_26_sub_41.inkml -> data/train/522.png
# Converted: archive/CROHME_training_2011/TrainData2_26_sub_43.inkml -> data/train/523.png
# Converted: archive/CROHME_training_2011/TrainData2_26_sub_46.inkml -> data/train/524.png
# Converted: archive/CROHME_training_2011/TrainData2_26_sub_49.inkml -> data/train/525.png
# Converted: archive/CROHME_training_2011/TrainData2_26_sub_51.inkml -> data/train/526.png
# Converted: archive/CROHME_training_2011/TrainData2_26_sub_6.inkml -> data/train/527.png
# Converted: archive/CROHME_training_2011/TrainData2_26_sub_61.inkml -> data/train/528.png
# Converted: archive/CROHME_training_2011/TrainData2_26_sub_63.inkml -> data/train/529.png
# Converted: archive/CROHME_training_2011/TrainData2_26_sub_71.inkml -> data/train/530.png
# Converted: archive/CROHME_training_2011/TrainData2_26_sub_73.inkml -> data/train/531.png
# Converted: archive/CROHME_training_2011/TrainData2_26_sub_88.inkml -> data/train/532.png
# Converted: archive/CROHME_training_2011/TrainData2_26_sub_9.inkml -> data/train/533.png
# Converted: archive/CROHME_training_2011/TrainData2_26_sub_95.inkml -> data/train/534.png
# Converted: archive/CROHME_training_2011/TrainData2_26_sub_98.inkml -> data/train/535.png
# Converted: archive/CROHME_training_2011/TrainData2_2_sub_1.inkml -> data/train/536.png
# Converted: archive/CROHME_training_2011/TrainData2_2_sub_11.inkml -> data/train/537.png
# Converted: archive/CROHME_training_2011/TrainData2_2_sub_13.inkml -> data/train/538.png
# Converted: archive/CROHME_training_2011/TrainData2_2_sub_15.inkml -> data/train/539.png
# Converted: archive/CROHME_training_2011/TrainData2_2_sub_17.inkml -> data/train/540.png
# Converted: archive/CROHME_training_2011/TrainData2_2_sub_20.inkml -> data/train/541.png
# Converted: archive/CROHME_training_2011/TrainData2_2_sub_29.inkml -> data/train/542.png
# ...
# Converted: archive/TrainINKML_2013/formulaire037-equation001.inkml -> data/train/9544.png
# Converted: archive/TrainINKML_2013/formulaire037-equation002.inkml -> data/train/9545.png
# Converted: archive/TrainINKML_2013/formulaire037-equation003.inkml -> data/train/9546.png
# Converted: archive/TrainINKML_2013/formulaire037-equation005.inkml -> data/train/9547.png
# Converted: archive/TrainINKML_2013/formulaire037-equation006.inkml -> data/train/9548.png
# Converted: archive/TrainINKML_2013/formulaire037-equation007.inkml -> data/train/9549.png
# Converted: archive/TrainINKML_2013/formulaire037-equation008.inkml -> data/train/9550.png
# Converted: archive/TrainINKML_2013/formulaire037-equation009.inkml -> data/train/9551.png
# Converted: archive/TrainINKML_2013/formulaire037-equation011.inkml -> data/train/9552.png
# Converted: archive/TrainINKML_2013/formulaire037-equation012.inkml -> data/train/9553.png
# Converted: archive/TrainINKML_2013/formulaire037-equation013.inkml -> data/train/9554.png
# Converted: archive/TrainINKML_2013/formulaire037-equation014.inkml -> data/train/9555.png
# Converted: archive/TrainINKML_2013/formulaire037-equation015.inkml -> data/train/9556.png
# Converted: archive/TrainINKML_2013/formulaire037-equation016.inkml -> data/train/9557.png
# Converted: archive/TrainINKML_2013/formulaire037-equation018.inkml -> data/train/9558.png
# Converted: archive/TrainINKML_2013/formulaire037-equation019.inkml -> data/train/9559.png
# Converted: archive/TrainINKML_2013/formulaire037-equation020.inkml -> data/train/9560.png
# Converted: archive/TrainINKML_2013/formulaire037-equation021.inkml -> data/train/9561.png
# Converted: archive/TrainINKML_2013/formulaire037-equation022.inkml -> data/train/9562.png
# Converted: archive/TrainINKML_2013/formulaire037-equation023.inkml -> data/train/9563.png
# Converted: archive/TrainINKML_2013/formulaire037-equation024.inkml -> data/train/9564.png
# Converted: archive/TrainINKML_2013/formulaire037-equation025.inkml -> data/train/9565.png
# Converted: archive/TrainINKML_2013/formulaire037-equation026.inkml -> data/train/9566.png
# Converted: archive/TrainINKML_2013/formulaire037-equation028.inkml -> data/train/9567.png
# Converted: archive/TrainINKML_2013/formulaire037-equation029.inkml -> data/train/9568.png
# Converted: archive/TrainINKML_2013/formulaire037-equation031.inkml -> data/train/9569.png
# Converted: archive/TrainINKML_2013/formulaire037-equation032.inkml -> data/train/9570.png
# Converted: archive/TrainINKML_2013/formulaire037-equation033.inkml -> data/train/9571.png
# Converted: archive/TrainINKML_2013/formulaire037-equation034.inkml -> data/train/9572.png
# Converted: archive/TrainINKML_2013/formulaire037-equation036.inkml -> data/train/9573.png
# Converted: archive/TrainINKML_2013/formulaire037-equation037.inkml -> data/train/9574.png
# Converted: archive/TrainINKML_2013/formulaire037-equation038.inkml -> data/train/9575.png
# Converted: archive/TrainINKML_2013/formulaire037-equation041.inkml -> data/train/9576.png
# Converted: archive/TrainINKML_2013/formulaire037-equation042.inkml -> data/train/9577.png
# Converted: archive/TrainINKML_2013/formulaire037-equation043.inkml -> data/train/9578.png
# Converted: archive/TrainINKML_2013/formulaire037-equation045.inkml -> data/train/9579.png
# Converted: archive/TrainINKML_2013/formulaire037-equation046.inkml -> data/train/9580.png
# Converted: archive/TrainINKML_2013/formulaire037-equation047.inkml -> data/train/9581.png
# Converted: archive/TrainINKML_2013/formulaire037-equation048.inkml -> data/train/9582.png
# Converted: archive/TrainINKML_2013/formulaire037-equation049.inkml -> data/train/9583.png
# Converted: archive/TrainINKML_2013/formulaire037-equation050.inkml -> data/train/9584.png
# Converted: archive/TrainINKML_2013/formulaire037-equation051.inkml -> data/train/9585.png
# Converted: archive/TrainINKML_2013/formulaire037-equation052.inkml -> data/train/9586.png
# Converted: archive/TrainINKML_2013/formulaire037-equation053.inkml -> data/train/9587.png
# Converted: archive/TrainINKML_2013/formulaire037-equation054.inkml -> data/train/9588.png
# Converted: archive/TrainINKML_2013/formulaire037-equation055.inkml -> data/train/9589.png
# Converted: archive/TrainINKML_2013/formulaire037-equation056.inkml -> data/train/9590.png
# Converted: archive/TrainINKML_2013/formulaire037-equation057.inkml -> data/train/9591.png
# Converted: archive/TrainINKML_2013/formulaire037-equation058.inkml -> data/train/9592.png
# Converted: archive/TrainINKML_2013/formulaire037-equation061.inkml -> data/train/9593.png
# Converted: archive/TrainINKML_2013/formulaire037-equation062.inkml -> data/train/9594.png
# Converted: archive/TrainINKML_2013/formulaire037-equation063.inkml -> data/train/9595.png
# Converted: archive/TrainINKML_2013/formulaire037-equation064.inkml -> data/train/9596.png
# Converted: archive/TrainINKML_2013/formulaire037-equation065.inkml -> data/train/9597.png
# Converted: archive/TrainINKML_2013/formulaire037-equation066.inkml -> data/train/9598.png
# Converted: archive/TrainINKML_2013/formulaire037-equation068.inkml -> data/train/9599.png
# Converted: archive/TrainINKML_2013/formulaire037-equation070.inkml -> data/train/9600.png
# Converted: archive/TrainINKML_2013/formulaire037-equation071.inkml -> data/train/9601.png
# Converted: archive/TrainINKML_2013/formulaire037-equation072.inkml -> data/train/9602.png
# Converted: archive/TrainINKML_2013/formulaire037-equation073.inkml -> data/train/9603.png
# Converted: archive/TrainINKML_2013/formulaire038-equation000.inkml -> data/train/9604.png
# Converted: archive/TrainINKML_2013/formulaire038-equation001.inkml -> data/train/9605.png
# Converted: archive/TrainINKML_2013/formulaire038-equation003.inkml -> data/train/9606.png
# Converted: archive/TrainINKML_2013/formulaire038-equation004.inkml -> data/train/9607.png
# Converted: archive/TrainINKML_2013/formulaire038-equation005.inkml -> data/train/9608.png
# Converted: archive/TrainINKML_2013/formulaire038-equation006.inkml -> data/train/9609.png
# Converted: archive/TrainINKML_2013/formulaire038-equation007.inkml -> data/train/9610.png
# Converted: archive/TrainINKML_2013/formulaire038-equation008.inkml -> data/train/9611.png
# Converted: archive/TrainINKML_2013/formulaire038-equation009.inkml -> data/train/9612.png
# Converted: archive/TrainINKML_2013/formulaire038-equation011.inkml -> data/train/9613.png
# Converted: archive/TrainINKML_2013/formulaire038-equation012.inkml -> data/train/9614.png
# Converted: archive/TrainINKML_2013/formulaire038-equation013.inkml -> data/train/9615.png
# Converted: archive/TrainINKML_2013/formulaire038-equation014.inkml -> data/train/9616.png
# Converted: archive/TrainINKML_2013/formulaire038-equation016.inkml -> data/train/9617.png
# Converted: archive/TrainINKML_2013/formulaire038-equation018.inkml -> data/train/9618.png
# Converted: archive/TrainINKML_2013/formulaire038-equation019.inkml -> data/train/9619.png
# Converted: archive/TrainINKML_2013/formulaire038-equation022.inkml -> data/train/9620.png
# Converted: archive/TrainINKML_2013/formulaire038-equation023.inkml -> data/train/9621.png
# Converted: archive/TrainINKML_2013/formulaire038-equation024.inkml -> data/train/9622.png
# Converted: archive/TrainINKML_2013/formulaire038-equation026.inkml -> data/train/9623.png
# Converted: archive/TrainINKML_2013/formulaire038-equation027.inkml -> data/train/9624.png
# Converted: archive/TrainINKML_2013/formulaire038-equation028.inkml -> data/train/9625.png
# Converted: archive/TrainINKML_2013/formulaire038-equation030.inkml -> data/train/9626.png
# Converted: archive/TrainINKML_2013/formulaire038-equation031.inkml -> data/train/9627.png
# Converted: archive/TrainINKML_2013/formulaire038-equation032.inkml -> data/train/9628.png
# Converted: archive/TrainINKML_2013/formulaire038-equation033.inkml -> data/train/9629.png
# Converted: archive/TrainINKML_2013/formulaire038-equation036.inkml -> data/train/9630.png
# Converted: archive/TrainINKML_2013/formulaire038-equation037.inkml -> data/train/9631.png
# Converted: archive/TrainINKML_2013/formulaire038-equation038.inkml -> data/train/9632.png
# Converted: archive/TrainINKML_2013/formulaire038-equation039.inkml -> data/train/9633.png
# Converted: archive/TrainINKML_2013/formulaire038-equation041.inkml -> data/train/9634.png
# Converted: archive/TrainINKML_2013/formulaire038-equation042.inkml -> data/train/9635.png
# Converted: archive/TrainINKML_2013/formulaire038-equation043.inkml -> data/train/9636.png
# Converted: archive/TrainINKML_2013/formulaire038-equation044.inkml -> data/train/9637.png
# Converted: archive/TrainINKML_2013/formulaire038-equation046.inkml -> data/train/9638.png
# Converted: archive/TrainINKML_2013/formulaire038-equation047.inkml -> data/train/9639.png
# Converted: archive/TrainINKML_2013/formulaire038-equation048.inkml -> data/train/9640.png
# Converted: archive/TrainINKML_2013/formulaire038-equation049.inkml -> data/train/9641.png
# Converted: archive/TrainINKML_2013/formulaire038-equation051.inkml -> data/train/9642.png
# Converted: archive/TrainINKML_2013/formulaire038-equation052.inkml -> data/train/9643.png
# Converted: archive/TrainINKML_2013/formulaire038-equation053.inkml -> data/train/9644.png
# Converted: archive/TrainINKML_2013/formulaire038-equation055.inkml -> data/train/9645.png
# Converted: archive/TrainINKML_2013/formulaire038-equation056.inkml -> data/train/9646.png
# Converted: archive/TrainINKML_2013/formulaire038-equation057.inkml -> data/train/9647.png
# Converted: archive/TrainINKML_2013/formulaire038-equation058.inkml -> data/train/9648.png
# Converted: archive/TrainINKML_2013/formulaire038-equation061.inkml -> data/train/9649.png
# Converted: archive/TrainINKML_2013/formulaire038-equation062.inkml -> data/train/9650.png
# Converted: archive/TrainINKML_2013/formulaire038-equation063.inkml -> data/train/9651.png
# Converted: archive/TrainINKML_2013/formulaire038-equation064.inkml -> data/train/9652.png
# Converted: archive/TrainINKML_2013/formulaire038-equation065.inkml -> data/train/9653.png
# Converted: archive/TrainINKML_2013/formulaire038-equation066.inkml -> data/train/9654.png
# Converted: archive/TrainINKML_2013/formulaire038-equation067.inkml -> data/train/9655.png
# Converted: archive/TrainINKML_2013/formulaire038-equation068.inkml -> data/train/9656.png
# Converted: archive/TrainINKML_2013/formulaire038-equation070.inkml -> data/train/9657.png
# Converted: archive/TrainINKML_2013/formulaire038-equation071.inkml -> data/train/9658.png
# Converted: archive/TrainINKML_2013/formulaire038-equation072.inkml -> data/train/9659.png
# Converted: archive/TrainINKML_2013/formulaire038-equation073.inkml -> data/train/9660.png
# Converted: archive/TrainINKML_2013/formulaire038-equation074.inkml -> data/train/9661.png
# Converted: archive/TrainINKML_2013/formulaire039-equation000.inkml -> data/train/9662.png
# Converted: archive/TrainINKML_2013/formulaire039-equation001.inkml -> data/train/9663.png
# Converted: archive/TrainINKML_2013/formulaire039-equation003.inkml -> data/train/9664.png
# Converted: archive/TrainINKML_2013/formulaire039-equation005.inkml -> data/train/9665.png
# Converted: archive/TrainINKML_2013/formulaire039-equation006.inkml -> data/train/9666.png
# Converted: archive/TrainINKML_2013/formulaire039-equation007.inkml -> data/train/9667.png
# Converted: archive/TrainINKML_2013/formulaire039-equation008.inkml -> data/train/9668.png
# Converted: archive/TrainINKML_2013/formulaire039-equation011.inkml -> data/train/9669.png
# Converted: archive/TrainINKML_2013/formulaire039-equation012.inkml -> data/train/9670.png
# Converted: archive/TrainINKML_2013/formulaire039-equation013.inkml -> data/train/9671.png
# Converted: archive/TrainINKML_2013/formulaire039-equation016.inkml -> data/train/9672.png
# Converted: archive/TrainINKML_2013/formulaire039-equation017.inkml -> data/train/9673.png
# Converted: archive/TrainINKML_2013/formulaire039-equation018.inkml -> data/train/9674.png
# Converted: archive/TrainINKML_2013/formulaire039-equation019.inkml -> data/train/9675.png
# Converted: archive/TrainINKML_2013/formulaire039-equation020.inkml -> data/train/9676.png
# Converted: archive/TrainINKML_2013/formulaire039-equation021.inkml -> data/train/9677.png
# Converted: archive/TrainINKML_2013/formulaire039-equation022.inkml -> data/train/9678.png
# Converted: archive/TrainINKML_2013/formulaire039-equation024.inkml -> data/train/9679.png
# Converted: archive/TrainINKML_2013/formulaire039-equation025.inkml -> data/train/9680.png
# Converted: archive/TrainINKML_2013/formulaire039-equation027.inkml -> data/train/9681.png
# Converted: archive/TrainINKML_2013/formulaire039-equation028.inkml -> data/train/9682.png
# Converted: archive/TrainINKML_2013/formulaire039-equation030.inkml -> data/train/9683.png
# Converted: archive/TrainINKML_2013/formulaire039-equation031.inkml -> data/train/9684.png
# Converted: archive/TrainINKML_2013/formulaire039-equation033.inkml -> data/train/9685.png
# Converted: archive/TrainINKML_2013/formulaire039-equation034.inkml -> data/train/9686.png
# Converted: archive/TrainINKML_2013/formulaire039-equation036.inkml -> data/train/9687.png
# Converted: archive/TrainINKML_2013/formulaire039-equation037.inkml -> data/train/9688.png
# Converted: archive/TrainINKML_2013/formulaire039-equation038.inkml -> data/train/9689.png
# Converted: archive/TrainINKML_2013/formulaire039-equation040.inkml -> data/train/9690.png
# Converted: archive/TrainINKML_2013/formulaire039-equation041.inkml -> data/train/9691.png
# Converted: archive/TrainINKML_2013/formulaire039-equation042.inkml -> data/train/9692.png
# Converted: archive/TrainINKML_2013/formulaire039-equation043.inkml -> data/train/9693.png
# Converted: archive/TrainINKML_2013/formulaire039-equation044.inkml -> data/train/9694.png
# Converted: archive/TrainINKML_2013/formulaire039-equation045.inkml -> data/train/9695.png
# Converted: archive/TrainINKML_2013/formulaire039-equation046.inkml -> data/train/9696.png
# Converted: archive/TrainINKML_2013/formulaire039-equation047.inkml -> data/train/9697.png
# Converted: archive/TrainINKML_2013/formulaire039-equation048.inkml -> data/train/9698.png
# Converted: archive/TrainINKML_2013/formulaire039-equation049.inkml -> data/train/9699.png
# Converted: archive/TrainINKML_2013/formulaire039-equation050.inkml -> data/train/9700.png
# Converted: archive/TrainINKML_2013/formulaire039-equation051.inkml -> data/train/9701.png
# Converted: archive/TrainINKML_2013/formulaire039-equation052.inkml -> data/train/9702.png
# Converted: archive/TrainINKML_2013/formulaire039-equation053.inkml -> data/train/9703.png
# Converted: archive/TrainINKML_2013/formulaire039-equation054.inkml -> data/train/9704.png
# Converted: archive/TrainINKML_2013/formulaire039-equation055.inkml -> data/train/9705.png
# Converted: archive/TrainINKML_2013/formulaire039-equation056.inkml -> data/train/9706.png
# Converted: archive/TrainINKML_2013/formulaire039-equation057.inkml -> data/train/9707.png
# Converted: archive/TrainINKML_2013/formulaire039-equation058.inkml -> data/train/9708.png
# Converted: archive/TrainINKML_2013/formulaire039-equation061.inkml -> data/train/9709.png
# Converted: archive/TrainINKML_2013/formulaire039-equation062.inkml -> data/train/9710.png
# Converted: archive/TrainINKML_2013/formulaire039-equation063.inkml -> data/train/9711.png
# Converted: archive/TrainINKML_2013/formulaire039-equation065.inkml -> data/train/9712.png
# Converted: archive/TrainINKML_2013/formulaire039-equation066.inkml -> data/train/9713.png
# Converted: archive/TrainINKML_2013/formulaire039-equation067.inkml -> data/train/9714.png
# Converted: archive/TrainINKML_2013/formulaire039-equation068.inkml -> data/train/9715.png
# Converted: archive/TrainINKML_2013/formulaire039-equation070.inkml -> data/train/9716.png
# Converted: archive/TrainINKML_2013/formulaire039-equation071.inkml -> data/train/9717.png
# Converted: archive/TrainINKML_2013/formulaire039-equation072.inkml -> data/train/9718.png
# Converted: archive/TrainINKML_2013/formulaire039-equation073.inkml -> data/train/9719.png
# Converted: archive/TrainINKML_2013/formulaire039-equation074.inkml -> data/train/9720.png
# Successes: 9721, Failures: 1630
